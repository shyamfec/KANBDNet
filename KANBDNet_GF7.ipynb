# %%
import glob
import sys
import random
import warnings
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import *
import tifffile as tiff
from tfkan import layers
from tfkan.layers import DenseKAN, Conv2DKAN
from tensorflow.nn import silu
from tensorflow.nn import depth_to_space, space_to_depth

# %%
# img = tiff.imread("G:/Segmentation _Multisensor/building/GF7/Test/image/Lanzhou_155.tif") 
# plt.imshow(img)
# plt.imsave("G:/Segmentation _Multisensor/building/Paper/img/GF7_img3.png",img)
# gt = tiff.imread("G:/Segmentation _Multisensor/building/GF7/Test/label/Lanzhou_155.tif") 
# plt.imshow(gt,cmap='gray')
# plt.imsave("G:/Segmentation _Multisensor/building/Paper/img/GF7_gt3.png",gt, cmap='gray')

# %%
def get_dataset(X_dir, y_dir):
    
    num_samples = len(X_dir)
    X = []
    y = []
    
    for i in range(num_samples):
        X.append(tiff.imread(X_dir[i]))
        y.append((tiff.imread(y_dir[i]))/255)
    
    y = np.reshape(y, (-1, 512, 512, 1))
    return np.array(X), np.array(y)

# %%
import glob
import matplotlib.pyplot as plt
import numpy as np

x_train = glob.glob("G:/Segmentation _Multisensor/building/GF7/Train/image/*.tif")
y_train = glob.glob("G:/Segmentation _Multisensor/building/GF7/Train/label/*.tif")

x_val = glob.glob("G:/Segmentation _Multisensor/building/GF7/Val/image/*.tif")
y_val = glob.glob("G:/Segmentation _Multisensor/building/GF7/Val/label/*.tif")

x_train.sort()
y_train.sort()
x_val.sort()
y_val.sort()

print(len(x_train), len(y_train), len(x_val), len(y_val))

x_train, y_train = get_dataset(x_train, y_train)
x_val, y_val = get_dataset(x_val, y_val)
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape)
# Out:
# 3106 3106 1034 1034
# (3106, 512, 512, 4) (3106, 512, 512, 1) (1034, 512, 512, 4) (1034, 512, 512, 1)

# %%
def kan_c(x,f,k):
    c22 = tf.keras.models.Sequential(Conv2DKAN(filters=f, kernel_size=k, strides=1, padding='same', kan_kwargs={'grid_size': 3}))
    c2 = c22(x)
    return c2

# %%
def Skip_layer(x1,x2):
    _,h1,w1,f1 = x1.shape
    _,h2,w2,f2 = x2.shape
    
    y1 = AveragePooling2D((h1//16,w1//16),(h1//16,w1//16))(x1)
    y2 = AveragePooling2D((h2//16,w2//16),(h2//16,w2//16))(x2)

    s1 = Reshape([16, 16, f1//4, 4])(y1)
    s1 = Permute([1, 2, 4, 3])(s1)
    s2 = Reshape([16, 16, f2//4, 4])(y2)
    s2 = Permute([1, 2, 4, 3])(s2)
    
    q0 = Concatenate()([s1[:,:,:,0],s2[:,:,:,0]])
    q1 = Concatenate()([s1[:,:,:,1],s2[:,:,:,1]])
    q2 = Concatenate()([s1[:,:,:,2],s2[:,:,:,2]])
    q3 = Concatenate()([s1[:,:,:,3],s2[:,:,:,3]])
   
    c1 = kan_c(q0,f1//4,3)
    c2 = kan_c(q1,f1//4,3)
    c3 = kan_c(q2,f1//4,3)
    c4 = kan_c(q3,f1//4,3)

    c = Concatenate()([c1,c2,c3,c4])

    y = tf.math.reduce_mean(c, axis=3, keepdims=True, name=None)
    y = Activation('sigmoid')(y)

    m1 = Multiply()([c,y])
    eff = kan_c(m1,f2,1)
    
    eff = experimental.preprocessing.Resizing(h2, w2)(eff)
    eff = Add()([eff,x2])
    return eff

# %%
def  Dense_multiscale_feature_extraction(x):
    _,h,w,f = x.shape
    y = AveragePooling2D((h//16,w//16),(h//16,w//16))(x)
    get_channel = f//4
    x_ = Reshape([16,16,get_channel,4])(y)
    x_ = Permute([1,2,4,3])(x_)
    x0 = x_[:,:,:,0]
    x1 = x_[:,:,:,1]
    x2 = x_[:,:,:,2]
    x3 = x_[:,:,:,3]
    x0 = DepthwiseConv2D((3,3),1,dilation_rate = (1,1),padding='same')(x0)
    x0 = kan_c(x0,f//4,3)
    x1 = Concatenate()([x0,x1])
    x1 = DepthwiseConv2D((3,3),1,dilation_rate = (2,2),padding='same')(x1)
    x1 = kan_c(x1,f//4,3)
    x2 = Concatenate()([x1,x2])
    x2 = DepthwiseConv2D((3,3),1,dilation_rate = (4,4),padding='same')(x2)
    x2 = kan_c(x2,f//4,3)
    x3 = Concatenate()([x2,x3])
    x3 = DepthwiseConv2D((3,3),1,dilation_rate = (8,8),padding='same')(x3)
    x3 = kan_c(x3,f//4,3)
    y = concatenate([x0,x1,x2,x3], axis=3)
    y = kan_c(y,f,1)
    y = experimental.preprocessing.Resizing(h, w)(y)
    x = Add()([x,y])
    return x

# %%
def bnprelu(x):
    bn = BatchNormalization()(x)
    act = Activation('selu')(bn)
    return act
def conv(x,nOut,kSize,strides,padding,dilation=(1,1),groups=1,bn_acti=False,bias=False):
    output = Conv2D(nOut,kSize,strides=strides,padding=padding,dilation_rate=dilation,groups=groups, use_bias=bias)(x)
    if bn_acti:
        output = bnprelu(output)
    return output
def Split(x):
    _,width,height,channel = x.shape
    get_channel = channel//2
    x_ = Reshape([width,height,get_channel,2])(x)
    x_ = Permute([1,2,4,3])(x_)
    x0 = x_[:,:,:,0]
    x1 = x_[:,:,:,1]
    return x0,x1
def Branch1(x,c,d=1,kSize=3,dkSize=3):
    _,h,w,f = x.shape
    br1 = conv(x,c,kSize,1,padding='same',bn_acti=True)
    br2 = conv(br1,c,kSize,1,padding='same',bn_acti=True)
    br3 = conv(br1,c,kSize,1,padding='same',bn_acti=True)
    br = br1+br1+br2
    output = Activation('sigmoid')(br)
    output = Multiply()([x,output])
    return output,br
def Branch2(x,c,d=1,kSize=3,dkSize=3):
    _,h,w,f = x.shape
    br1 = conv(x,c,kSize,1,padding='same',bn_acti=True)
    br = AveragePooling2D((h//16,w//16),(h//16,w//16))(br1)
    br2 = kan_c(br,c,1)
    br3 = kan_c(br,c,3)
    br2 = experimental.preprocessing.Resizing(h, w)(br2)
    br3 = experimental.preprocessing.Resizing(h, w)(br3)
    br = br1+br2+br3
    output = Activation('sigmoid')(br)
    output = Multiply()([x,output])
    return output,br
def  Split_wise_feature_extraction(x,d=1,dropout=0,p=0.5):
    _,h,w,nIn = x.shape
    c = nIn-int(nIn*(1-p))
    output1, output2 = Split(x)
    output1,out1 = Branch1(output1,c,d)
    output2,out2 = Branch2(output2,c,d)
    output = Concatenate()([output1, output2])
    out = Concatenate()([out1, out2])
    output = conv(output,nIn, 1, 1, padding='valid', bn_acti=True)
    out = conv(out,nIn, 1, 1, padding='valid', bn_acti=True)
    output = Add()([output,out])
    return output

# %%
def jaccard(y_true, y_pred, smooth=1e-7):
    intersection = tf.reduce_sum(y_true * y_pred, axis=(1, 2))
    union = tf.reduce_sum(y_true, axis=(1, 2)) +tf.reduce_sum(y_pred,axis=(1, 2)) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    return jaccard
def boundary_JI(true, pred, theta0=3, theta=5):
    n, h, w, c = pred.shape
    kernel_theta0 = [theta0, theta0]
    kernel_theta = [theta, theta]
    one_hot_gt = true
    one_hot_gt_neg = 1.0 - one_hot_gt
    gt_b = tf.nn.max_pool2d(tf.transpose(one_hot_gt_neg, perm=[0, 3, 1, 2]), ksize=kernel_theta0,strides=1,padding='SAME')
    gt_b = tf.transpose(gt_b, perm=[0, 2, 3, 1]) 
    gt_b -= one_hot_gt_neg
    
    pred_neg = 1.0 - pred
    pred_b = tf.nn.max_pool2d(tf.transpose(pred_neg, perm=[0, 3, 1, 2]), ksize=kernel_theta0,strides=1,padding='SAME')
    pred_b = tf.transpose(pred_b, perm=[0, 2, 3, 1])
    pred_b -= pred_neg
    gt_b_ext = tf.nn.max_pool2d(tf.transpose(gt_b, perm=[0, 3, 1, 2]),ksize=kernel_theta,strides=1,padding='SAME')
    gt_b_ext = tf.transpose(gt_b_ext, perm=[0, 2, 3, 1])
    pred_b_ext = tf.nn.max_pool2d(tf.transpose(pred_b, perm=[0, 3, 1, 2]), ksize=kernel_theta,strides=1,padding='SAME')
    pred_b_ext = tf.transpose(pred_b_ext, perm=[0, 2, 3, 1])
    
    ji = jaccard(gt_b_ext, pred_b_ext)
    return ji

# %%
def KANBDNet(input_size=(512,512,4)):
    inputs = Input(input_size)

    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (inputs)
    c1 = Split_wise_feature_extraction(c1,dropout=0,p=0.5)
    c1 = Split_wise_feature_extraction(c1,dropout=0,p=0.5)
    p1 = MaxPooling2D((2, 2)) (c1)

    c2 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p1)
    c2 = Split_wise_feature_extraction(c2,dropout=0,p=0.5)
    c2 = Split_wise_feature_extraction(c2,dropout=0,p=0.5)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p2)
    c3 = Split_wise_feature_extraction(c3,dropout=0,p=0.5)
    c3 = Split_wise_feature_extraction(c3,dropout=0,p=0.5)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p3)
    c4 = Dropout(0.2) (c4)
    c4 = Split_wise_feature_extraction(c4,dropout=0,p=0.5)
    c4 = Split_wise_feature_extraction(c4,dropout=0,p=0.5)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p4)
    c5 = Dropout(0.4) (c5)
    c5 = Dense_multiscale_feature_extraction(c5)

    u6 = Conv2DTranspose(32, (2, 2), activation='relu', strides=(2, 2), padding='same') (c5)
    m1 = Skip_layer(c5,c4)
    u6 = concatenate([u6, m1])
    c6 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u6)
    c6 = Dropout(0.2) (c6)

    u7 = Conv2DTranspose(32, (2, 2), activation='relu', strides=(2, 2), padding='same') (c6)
    m2 = Skip_layer(c5,c3)
    u7 = concatenate([u7, m2])
    c7 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u7)

    u8 = Conv2DTranspose(16, (2, 2), activation='relu', strides=(2, 2), padding='same') (c7)
    m3 = Skip_layer(c5,c2)
    u8 = concatenate([u8, m3])
    c8 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u8)

    u9 = Conv2DTranspose(16, (2, 2), activation='relu', strides=(2, 2), padding='same') (c8)
    m4 = Skip_layer(c5,c1)
    u9 = concatenate([u9, m4], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u9)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
model = KANBDNet()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[boundary_JI,'accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 4) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 16) 592         input_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 512, 512, 8,  0           conv2d[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 512, 512, 2,  0           reshape[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli (None, 512, 512, 8)  0           permute[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 512, 512, 8)  0           permute[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 512, 512, 8)  576         tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 8)  576         tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 512, 512, 8)  32          conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 512, 512, 8)  32          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512, 512, 8)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 512, 512, 8)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 16, 16, 8)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 512, 512, 8)  576         activation[0][0]
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 16, 16, 8)    536         average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512, 512, 8)  32          conv2d_2[0][0]
# __________________________________________________________________________________________________
# resizing (Resizing)             (None, 512, 512, 8)  0           sequential[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 16, 16, 8)    4760        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 512, 512, 8)  0           activation[0][0]
#                                                                  activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 512, 512, 8)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 512, 512, 8)  0           activation_4[0][0]
#                                                                  resizing[0][0]
# __________________________________________________________________________________________________
# resizing_1 (Resizing)           (None, 512, 512, 8)  0           sequential_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 512, 512, 8)  0           tf.__operators__.add[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 512, 512, 8)  0           tf.__operators__.add_2[0][0]
#                                                                  resizing_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 512, 512, 8)  0           tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512, 512, 8)  0           tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 512, 512, 8)  0           tf.__operators__.getitem[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 512, 512, 8)  0           tf.__operators__.getitem_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512, 512, 16) 0           multiply[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512, 512, 16) 0           tf.__operators__.add_1[0][0]
#                                                                  tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 512, 512, 16) 256         concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 512, 512, 16) 256         concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512, 512, 16) 64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512, 512, 16) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 512, 512, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 512, 512, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 512, 512, 16) 0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 512, 512, 8,  0           add[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 512, 512, 2,  0           reshape_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_3 (Sli (None, 512, 512, 8)  0           permute_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_2 (Sli (None, 512, 512, 8)  0           permute_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 512, 512, 8)  576         tf.__operators__.getitem_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 512, 512, 8)  576         tf.__operators__.getitem_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 512, 512, 8)  32          conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 512, 512, 8)  32          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 512, 512, 8)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 512, 512, 8)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 16, 16, 8)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 512, 512, 8)  576         activation_8[0][0]
# __________________________________________________________________________________________________
# sequential_2 (Sequential)       (None, 16, 16, 8)    536         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 512, 512, 8)  32          conv2d_8[0][0]
# __________________________________________________________________________________________________
# resizing_2 (Resizing)           (None, 512, 512, 8)  0           sequential_2[0][0]
# __________________________________________________________________________________________________
# sequential_3 (Sequential)       (None, 16, 16, 8)    4760        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_4 (TFOpLam (None, 512, 512, 8)  0           activation_8[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 512, 512, 8)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_6 (TFOpLam (None, 512, 512, 8)  0           activation_12[0][0]
#                                                                  resizing_2[0][0]
# __________________________________________________________________________________________________
# resizing_3 (Resizing)           (None, 512, 512, 8)  0           sequential_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_5 (TFOpLam (None, 512, 512, 8)  0           tf.__operators__.add_4[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_7 (TFOpLam (None, 512, 512, 8)  0           tf.__operators__.add_6[0][0]
#                                                                  resizing_3[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 512, 512, 8)  0           tf.__operators__.add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 512, 512, 8)  0           tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 512, 512, 8)  0           tf.__operators__.getitem_2[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 512, 512, 8)  0           tf.__operators__.getitem_3[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 512, 512, 16) 0           multiply_2[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 512, 512, 16) 0           tf.__operators__.add_5[0][0]
#                                                                  tf.__operators__.add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 512, 512, 16) 256         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 512, 512, 16) 256         concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 512, 512, 16) 64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 512, 512, 16) 64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 512, 512, 16) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 512, 512, 16) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 512, 512, 16) 0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 16) 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 256, 16) 2320        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 256, 256, 8,  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 256, 256, 2,  0           reshape_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_5 (Sli (None, 256, 256, 8)  0           permute_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli (None, 256, 256, 8)  0           permute_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 8)  576         tf.__operators__.getitem_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 256, 256, 8)  576         tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 256, 256, 8)  32          conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 256, 256, 8)  32          conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 256, 256, 8)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 256, 256, 8)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 16, 16, 8)    0           activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 8)  576         activation_16[0][0]
# __________________________________________________________________________________________________
# sequential_4 (Sequential)       (None, 16, 16, 8)    536         average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 256, 256, 8)  32          conv2d_15[0][0]
# __________________________________________________________________________________________________
# resizing_4 (Resizing)           (None, 256, 256, 8)  0           sequential_4[0][0]
# __________________________________________________________________________________________________
# sequential_5 (Sequential)       (None, 16, 16, 8)    4760        average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_8 (TFOpLam (None,
0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_19 (TFOpLa (None, 128, 128, 16) 0           tf.__operators__.add_18[0][0]
#                                                                  resizing_9[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 128, 128, 16) 0           tf.__operators__.add_17[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 128, 128, 16) 0           tf.__operators__.add_19[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 128, 128, 16) 0           tf.__operators__.getitem_8[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 128, 128, 16) 0           tf.__operators__.getitem_9[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 128, 32) 0           multiply_8[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 128, 128, 32) 0           tf.__operators__.add_17[0][0]
#                                                                  tf.__operators__.add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 128, 128, 32) 1024        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 128, 128, 32) 1024        concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 128, 128, 32) 128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 128, 128, 32) 128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 128, 128, 32) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 128, 128, 32) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 128, 32) 0           activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 128, 128, 16, 0           add_4[0][0]
# __________________________________________________________________________________________________
# permute_5 (Permute)             (None, 128, 128, 2,  0           reshape_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_11 (Sl (None, 128, 128, 16) 0           permute_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_10 (Sl (None, 128, 128, 16) 0           permute_5[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 128, 128, 16) 2304        tf.__operators__.getitem_11[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 128, 128, 16) 2304        tf.__operators__.getitem_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 128, 128, 16) 64          conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 128, 128, 16) 64          conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 128, 128, 16) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 128, 128, 16) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 16, 16, 16)   0           activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 128, 128, 16) 2304        activation_40[0][0]
# __________________________________________________________________________________________________
# sequential_10 (Sequential)      (None, 16, 16, 16)   1968        average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 128, 128, 16) 64          conv2d_34[0][0]
# __________________________________________________________________________________________________
# resizing_10 (Resizing)          (None, 128, 128, 16) 0           sequential_10[0][0]
# __________________________________________________________________________________________________
# sequential_11 (Sequential)      (None, 16, 16, 16)   17584       average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_20 (TFOpLa (None, 128, 128, 16) 0           activation_40[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 128, 128, 16) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_22 (TFOpLa (None, 128, 128, 16) 0           activation_44[0][0]
#                                                                  resizing_10[0][0]
# __________________________________________________________________________________________________
# resizing_11 (Resizing)          (None, 128, 128, 16) 0           sequential_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_21 (TFOpLa (None, 128, 128, 16) 0           tf.__operators__.add_20[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_23 (TFOpLa (None, 128, 128, 16) 0           tf.__operators__.add_22[0][0]
#                                                                  resizing_11[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 128, 128, 16) 0           tf.__operators__.add_21[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 128, 128, 16) 0           tf.__operators__.add_23[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 128, 128, 16) 0           tf.__operators__.getitem_10[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 128, 128, 16) 0           tf.__operators__.getitem_11[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 128, 128, 32) 0           multiply_10[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 128, 128, 32) 0           tf.__operators__.add_21[0][0]
#                                                                  tf.__operators__.add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 128, 128, 32) 1024        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 128, 128, 32) 1024        concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 128, 128, 32) 128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 128, 128, 32) 128         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 128, 128, 32) 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# ...
# tf.__operators__.getitem_43 (Sl (None, 16, 16, 4)    0           permute_14[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_15 (AveragePo (None, 16, 16, 32)   0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_16 (AveragePo (None, 16, 16, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# resizing_17 (Resizing)          (None, 64, 64, 32)   0           sequential_25[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_1 (TFOpLamb (None, 16, 16, 1)    0           concatenate_30[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 16, 16, 12)   0           tf.__operators__.getitem_36[0][0]
#                                                                  tf.__operators__.getitem_37[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 16, 16, 12)   0           tf.__operators__.getitem_38[0][0]
#                                                                  tf.__operators__.getitem_39[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 16, 16, 12)   0           tf.__operators__.getitem_40[0][0]
#                                                                  tf.__operators__.getitem_41[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 16, 16, 12)   0           tf.__operators__.getitem_42[0][0]
#                                                                  tf.__operators__.getitem_43[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 16, 16, 8, 4) 0           average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 16, 16, 4, 4) 0           average_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 64, 64, 32)   4128        add_8[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 32)   0           resizing_17[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 16, 16, 1)    0           tf.math.reduce_mean_1[0][0]
# __________________________________________________________________________________________________
# sequential_31 (Sequential)      (None, 16, 16, 8)    7136        concatenate_32[0][0]
# __________________________________________________________________________________________________
# sequential_32 (Sequential)      (None, 16, 16, 8)    7136        concatenate_33[0][0]
# __________________________________________________________________________________________________
# sequential_33 (Sequential)      (None, 16, 16, 8)    7136        concatenate_34[0][0]
# __________________________________________________________________________________________________
# sequential_34 (Sequential)      (None, 16, 16, 8)    7136        concatenate_35[0][0]
# __________________________________________________________________________________________________
# permute_15 (Permute)            (None, 16, 16, 4, 8) 0           reshape_15[0][0]
# __________________________________________________________________________________________________
# permute_16 (Permute)            (None, 16, 16, 4, 4) 0           reshape_16[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 64, 64, 64)   0           conv2d_transpose[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 16, 16, 32)   0           concatenate_30[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 16, 16, 32)   0           sequential_31[0][0]
#                                                                  sequential_32[0][0]
#                                                                  sequential_33[0][0]
#                                                                  sequential_34[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_44 (Sl (None, 16, 16, 8)    0           permute_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_45 (Sl (None, 16, 16, 4)    0           permute_16[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_46 (Sl (None, 16, 16, 8)    0           permute_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_47 (Sl (None, 16, 16, 4)    0           permute_16[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_48 (Sl (None, 16, 16, 8)    0           permute_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_49 (Sl (None, 16, 16, 4)    0           permute_16[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_50 (Sl (None, 16, 16, 8)    0           permute_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_51 (Sl (None, 16, 16, 4)    0           permute_16[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_25[0][0]
# __________________________________________________________________________________________________
# sequential_30 (Sequential)      (None, 16, 16, 32)   7520        multiply_17[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_2 (TFOpLamb (None, 16, 16, 1)    0           concatenate_36[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 16, 16, 12)   0           tf.__operators__.getitem_44[0][0]
#                                                                  tf.__operators__.getitem_45[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 16, 16, 12)   0           tf.__operators__.getitem_46[0][0]
#                                                                  tf.__operators__.getitem_47[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 16, 16, 12)   0           tf.__operators__.getitem_48[0][0]
#                                                                  tf.__operators__.getitem_49[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 16, 16, 12)   0           tf.__operators__.getitem_50[0][0]
#                                                                  tf.__operators__.getitem_51[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 64, 32)   0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# resizing_18 (Resizing)          (None, 128, 128, 32) 0           sequential_30[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 16, 16, 1)    0           tf.math.reduce_mean_2[0][0]
# __________________________________________________________________________________________________
# sequential_36 (Sequential)      (None, 16, 16, 8)    7136        concatenate_38[0][0]
# __________________________________________________________________________________________________
# sequential_37 (Sequential)      (None, 16, 16, 8)    7136        concatenate_39[0][0]
# __________________________________________________________________________________________________
# sequential_38 (Sequential)      (None, 16, 16, 8)    7136        concatenate_40[0][0]
# __________________________________________________________________________________________________
# sequential_39 (Sequential)      (None, 16, 16, 8)    7136        concatenate_41[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 128, 128, 32) 4128        dropout_2[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 128, 128, 32) 0           resizing_18[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 16, 16, 32)   0           concatenate_36[0][0]
#                                                                  activation_66[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 16, 16, 32)   0           sequential_36[0][0]
#                                                                  sequential_37[0][0]
#                                                                  sequential_38[0][0]
#                                                                  sequential_39[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 128, 128, 64) 0           conv2d_transpose_1[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# sequential_35 (Sequential)      (None, 16, 16, 16)   3920        multiply_18[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_mean_3 (TFOpLamb (None, 16, 16, 1)    0           concatenate_42[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_31[0][0]
# __________________________________________________________________________________________________
# resizing_19 (Resizing)          (None, 256, 256, 16) 0           sequential_35[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 16, 16, 1)    0           tf.math.reduce_mean_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 256, 256, 16) 2064        conv2d_54[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 256, 256, 16) 0           resizing_19[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 16, 16, 32)   0           concatenate_42[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 256, 256, 32) 0           conv2d_transpose_2[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# sequential_40 (Sequential)      (None, 16, 16, 16)   3920        multiply_19[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 256, 256, 16) 4624        concatenate_37[0][0]
# __________________________________________________________________________________________________
# resizing_20 (Resizing)          (None, 512, 512, 16) 0           sequential_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 512, 512, 16) 1040        conv2d_55[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 512, 512, 16) 0           resizing_20[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 512, 512, 32) 0           conv2d_transpose_3[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 512, 512, 16) 4624        concatenate_43[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 512, 512, 1)  17          conv2d_56[0][0]
# ==================================================================================================
# Total params: 427,921
# Trainable params: 390,177
# Non-trainable params: 37,744
# __________________________________________________________________________________________________

# %%
import math
import time
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_boundary_JI',mode='max',factor=0.5,patience=10,verbose=1,cooldown=1,min_delta=0.0001)
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_boundary_JI',min_delta=0.0001,patience=20,verbose=1,mode='max',restore_best_weights=True)
check_path = 'G:/Segmentation _Multisensor/building/Proposed/KANBDNet_GF4_up.h5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(check_path,monitor='val_boundary_JI',verbose=1,save_best_only=True,save_weights_only=True,mode='max')
t1 = time.time()
history = model.fit(x=x_train,y=y_train,validation_data=(x_val,y_val),batch_size=2,shuffle=True,verbose=1,epochs=300,
                    callbacks=[reduce_lr,early_stop,checkpoint])
t2 = time.time()
print(t2-t1)
# Out:
# Epoch 1/300
# 1553/1553 [==============================] - 557s 336ms/step - loss: 0.2828 - boundary_JI: 0.0651 - accuracy: 0.8797 - val_loss: 0.2311 - val_boundary_JI: 0.0701 - val_accuracy: 0.9055
#
# Epoch 00001: val_boundary_JI improved from -inf to 0.07014, saving model to G:/Segmentation _Multisensor/building/Proposed\KANBDNet_GF4_up.h5
# Epoch 2/300
# 1553/1553 [==============================] - 525s 338ms/step - loss: 0.2228 - boundary_JI: 0.0817 - accuracy: 0.9082 - val_loss: 0.2495 - val_boundary_JI: 0.0653 - val_accuracy: 0.9021
#
# Epoch 00002: val_boundary_JI did not improve from 0.07014
# Epoch 3/300
# 1553/1553 [==============================] - 524s 337ms/step - loss: 0.1955 - boundary_JI: 0.0908 - accuracy: 0.9203 - val_loss: 0.1895 - val_boundary_JI: 0.0912 - val_accuracy: 0.9234
#
# Epoch 00003: val_boundary_JI improved from 0.07014 to 0.09124, saving model to G:/Segmentation _Multisensor/building/Proposed\KANBDNet_GF4_up.h5
# Epoch 4/300
# 1553/1553 [==============================] - 522s 336ms/step - loss: 0.1830 - boundary_JI: 0.0972 - accuracy: 0.9265 - val_loss: 0.1678 - val_boundary_JI: 0.1004 - val_accuracy: 0.9319
#
# Epoch 00004: val_boundary_JI improved from 0.09124 to 0.10037, saving model to G:/Segmentation _Multisensor/building/Proposed\KANBDNet_GF4_up.h5
# Epoch 5/300
# 1553/1553 [==============================] - 523s 337ms/step - loss: 0.1682 - boundary_JI: 0.1031 - accuracy: 0.9324 - val_loss: 0.2271 - val_boundary_JI: 0.0649 - val_accuracy: 0.9086
#
# Epoch 00005: val_boundary_JI did not improve from 0.10037
# Epoch 6/300
# 1553/1553 [==============================] - 523s 337ms/step - loss: 0.1583 - boundary_JI: 0.1070 - accuracy: 0.9365 - val_loss: 0.1626 - val_boundary_JI: 0.0998 - val_accuracy: 0.9336
#
# Epoch 00006: val_boundary_JI did not improve from 0.10037
# Epoch 7/300
# 1553/1553 [==============================] - 525s 338ms/step - loss: 0.1569 - boundary_JI: 0.1077 - accuracy: 0.9373 - val_loss: 0.1442 - val_boundary_JI: 0.1153 - val_accuracy: 0.9419
#
# Epoch 00007: val_boundary_JI improved from 0.10037 to 0.11529, saving model to G:/Segmentation _Multisensor/building/Proposed\KANBDNet_GF4_up.h5
# Epoch 8/300
# 1553/1553 [==============================] - 525s 338ms/step - loss: 0.1489 - boundary_JI: 0.1114 - accuracy: 0.9406 - val_loss: 0.1447 - val_boundary_JI: 0.1183 - val_accuracy: 0.9423
#
# Epoch 00008: val_boundary_JI improved from 0.11529 to 0.11834, saving model to G:/Segmentation _Multisensor/building/Proposed\KANBDNet_GF4_up.h5
# Epoch 9/300
# 1553/1553 [==============================] - 525s 338ms/step - loss: 0.1430 - boundary_JI: 0.1144 - accuracy: 0.9429 - val_loss: 0.1562 - val_boundary_JI: 0.1109 - val_accuracy: 0.9399
#
# Epoch 00009: val_boundary_JI did not improve from 0.11834
# Epoch 10/300
# 1553/1553 [==============================] - 526s 339ms/step - loss: 0.1391 - boundary_JI: 0.1162 - accuracy: 0.9446 - val_loss: 0.1524 - val_boundary_JI: 0.1055 - val_accuracy: 0.9386
#
# Epoch 00010: val_boundary_JI did not improve from 0.11834
# Epoch 11/300
# 1553/1553 [==============================] - 527s 340ms/step - loss: 0.1360 - boundary_JI: 0.1177 - accuracy: 0.9459 - val_loss: 0.1346 - val_boundary_JI: 0.1220 - val_accuracy: 0.9470
#
# Epoch 00011: val_boundary_JI improved from 0.11834 to 0.12197, saving model to G:/Segmentation _Multisensor/building/Proposed\KANBDNet_GF4_up.h5
# Epoch
# 1553/1553 [==============================] - 512s 330ms/step - loss: 0.0717 - boundary_JI: 0.1661 - accuracy: 0.9708 - val_loss: 0.1301 - val_boundary_JI: 0.1565 - val_accuracy: 0.9572
#
# Epoch 00167: val_boundary_JI did not improve from 0.15797
# Epoch 168/300
# 1553/1553 [==============================] - 522s 336ms/step - loss: 0.0717 - boundary_JI: 0.1661 - accuracy: 0.9707 - val_loss: 0.1328 - val_boundary_JI: 0.1549 - val_accuracy: 0.9570
#
# Epoch 00168: val_boundary_JI did not improve from 0.15797
# Epoch 169/300
# 1553/1553 [==============================] - 515s 332ms/step - loss: 0.0718 - boundary_JI: 0.1662 - accuracy: 0.9707 - val_loss: 0.1304 - val_boundary_JI: 0.1565 - val_accuracy: 0.9572
#
# Epoch 00169: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Restoring model weights from the end of the best epoch.
#
# Epoch 00169: val_boundary_JI did not improve from 0.15797
# Epoch 00169: early stopping
# 87702.72516417503

# %%
model.load_weights('G:/Segmentation _Multisensor/building/Proposed/KANBDNet_GF4_up.h5')

# %%
gtappend = []
predappend =[]

addA = "G:/Segmentation _Multisensor/building/GF7/Test/image/"
addlabel = "G:/Segmentation _Multisensor/building/GF7/Test/label/"

for eg in os.listdir(addA):
    imageA = addA + str(eg)
    GT = addlabel + str(eg)
    x1 = plt.imread(imageA)
    x2 = plt.imread(GT)
    a = np.reshape(x1,(1,512,512,4))
    y = model.predict(a)
    y = np.reshape(y,(512,512))
    result = np.where(y>0.5,1,0)
    predappend.append(result)
    gtappend.append(x2/255)

g = np.stack(gtappend, axis=0)
p = np.stack(predappend, axis=0)

from sklearn.metrics import *
gt=(g.ravel()).astype('int')
pd=(p.ravel()).astype('int')
f1 = f1_score(gt,pd,average='macro')
kappa = cohen_kappa_score(gt,pd)
accuracy = accuracy_score(gt,pd)
jaccard = jaccard_score(gt,pd,average='macro')
precision = precision_score(gt,pd,average='macro')
recall = recall_score(gt,pd,average='macro')
print(np.unique(gt),np.unique(pd))
print("F1 SCORE:", f1)
print("Kappa:",kappa)
print("Accuracy:",accuracy)
print("Jaccard Score:",jaccard)
print("Precision:",precision)
print("Recall:",recall)
# Out:
# [0 1] [0 1]
# F1 SCORE: 0.9216031741841326
# Kappa: 0.8432476149807597
# Accuracy: 0.9592345822836466
# Jaccard Score: 0.8593216525002758
# Precision: 0.9354252268723353
# Recall: 0.9090878605327543

# %%
def get_dice(y_true, y_pred):
    intersection = np.sum(y_true * y_pred, axis=(0, 1, 2))
    union = np.sum(y_true**2, axis=(0, 1, 2)) + np.sum(y_pred**2, axis=(0, 1, 2))
    dc = 2 * intersection / union
    return dc
 
dice_coeff = get_dice(g, p)
print("dc = ",np.mean(dice_coeff))
# Out:
# dc =  0.867287587599954

# %%
import tensorflow as tf
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2_as_graph

def get_flops(model, batch_size=None):
    if batch_size is None:
        batch_size = 1

    real_model =tf.function(model).get_concrete_function(tf.TensorSpec([batch_size] +model.inputs[0].shape[1:], model.inputs[0].dtype))
    frozen_func, graph_def =convert_variables_to_constants_v2_as_graph(real_model)

    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
    flops = tf.compat.v1.profiler.profile(graph=frozen_func.graph,
                                            run_meta=run_meta,cmd='op', options=opts)
    return flops.total_float_ops

flops = get_flops(model,2)
flops
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\envs\Tensorflow_GPU_2_5\lib\site-packages\tensorflow\python\ops\nn_ops.py:4940: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# 17495840048

# %%
from skimage.io import imsave, imread
import time
img = tiff.imread("G:/Segmentation _Multisensor/building/GF7/Test/image/Guangzhou_49.tif")
y_test = tiff.imread("G:/Segmentation _Multisensor/building/GF7/Test/label/Guangzhou_49.tif")
x_test = np.expand_dims(img,axis=0)
t0 = time.time()
y_pred = model.predict(x_test)
t1 = time.time()
print(t1-t0)
fig = plt.figure()
fig.figsize = (30,30)
y_pred = y_pred>0.5
ax = fig.add_subplot(1,3,1)
ax.imshow(np.reshape(x_test,(512,512,4)))
plt.axis('off')
plt.title("Image")

ax = fig.add_subplot(1,3,2)
ax.imshow(np.reshape(y_test,(512,512)),cmap="gray")
plt.axis('off')
plt.title("Ground-truth")

ax = fig.add_subplot(1,3,3)
ax.imshow(np.reshape(y_pred,(512,512)),cmap="gray")
plt.axis('off')
plt.title("Predicted image")
imsave("G:/Segmentation _Multisensor/building/Proposed/Results/pr/gf2/prop1_gf2.png", np.reshape(y_pred,(512,512)))
# Out:
# 10.22232961654663
# C:\Users\user\AppData\Local\Temp\ipykernel_398828\567217700.py:27: UserWarning: G:/Segmentation _Multisensor/building/Proposed/Results/pr/gf2/prop1_gf2.png is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave("G:/Segmentation _Multisensor/building/Proposed/Results/pr/gf2/prop1_gf2.png", np.reshape(y_pred,(512,512)))

# %%
from skimage.io import imsave, imread
import time
img = tiff.imread("G:/Segmentation _Multisensor/building/GF7/Test/image/Lanzhou_650.tif")
y_test = tiff.imread("G:/Segmentation _Multisensor/building/GF7/Test/label/Lanzhou_650.tif")
x_test = np.expand_dims(img,axis=0)
t0 = time.time()
y_pred = model.predict(x_test)
t1 = time.time()
print(t1-t0)
fig = plt.figure()
fig.figsize = (30,30)
y_pred = y_pred>0.5
ax = fig.add_subplot(1,3,1)
ax.imshow(np.reshape(x_test,(512,512,4)))
plt.axis('off')
plt.title("Image")

ax = fig.add_subplot(1,3,2)
ax.imshow(np.reshape(y_test,(512,512)),cmap="gray")
plt.axis('off')
plt.title("Ground-truth")

ax = fig.add_subplot(1,3,3)
ax.imshow(np.reshape(y_pred,(512,512)),cmap="gray")
plt.axis('off')
plt.title("Predicted image")
imsave("G:/Segmentation _Multisensor/building/Proposed/Results/pr/gf3/prop1_gf3.png", np.reshape(y_pred,(512,512)))
# Out:
# 0.1417980194091797
# C:\Users\user\AppData\Local\Temp\ipykernel_398828\1336316358.py:27: UserWarning: G:/Segmentation _Multisensor/building/Proposed/Results/pr/gf3/prop1_gf3.png is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave("G:/Segmentation _Multisensor/building/Proposed/Results/pr/gf3/prop1_gf3.png", np.reshape(y_pred,(512,512)))

# %%
from skimage.io import imsave, imread
import time
img = tiff.imread("G:/Segmentation _Multisensor/building/GF7/Test/image/Tianjin_970.tif")
y_test = tiff.imread("G:/Segmentation _Multisensor/building/GF7/Test/label/Tianjin_970.tif")
x_test = np.expand_dims(img,axis=0)
t0 = time.time()
y_pred = model.predict(x_test)
t1 = time.time()
print(t1-t0)
fig = plt.figure()
fig.figsize = (30,30)
y_pred = y_pred>0.5
ax = fig.add_subplot(1,3,1)
ax.imshow(np.reshape(x_test,(512,512,4)))
plt.axis('off')
plt.title("Image")

ax = fig.add_subplot(1,3,2)
ax.imshow(np.reshape(y_test,(512,512)),cmap="gray")
plt.axis('off')
plt.title("Ground-truth")

ax = fig.add_subplot(1,3,3)
ax.imshow(np.reshape(y_pred,(512,512)),cmap="gray")
plt.axis('off')
plt.title("Predicted image")
imsave("G:/Segmentation _Multisensor/building/Proposed/Results/pr/gf4/prop1_gf4.png", np.reshape(y_pred,(512,512)))
# Out:
# 0.11150550842285156
# C:\Users\user\AppData\Local\Temp\ipykernel_398828\630327129.py:27: UserWarning: G:/Segmentation _Multisensor/building/Proposed/Results/pr/gf4/prop1_gf4.png is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   imsave("G:/Segmentation _Multisensor/building/Proposed/Results/pr/gf4/prop1_gf4.png", np.reshape(y_pred,(512,512)))
